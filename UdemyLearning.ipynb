# %% [markdown]
# <a href="https://colab.research.google.com/github/The237/ANN_Train/blob/main/UdemyLearning.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !ls sample_data
# Out:
# anscombe.json		      mnist_test.csv
# california_housing_test.csv   mnist_train_small.csv
# california_housing_train.csv  README.md

# %%
from google.colab import drive
drive.mount('/gdrive')
# Out:
# Mounted at /gdrive

# %%
# !ls /gdrive/MyDrive
# Out:
# 'arbre a problems.docx'
#  attestation_immatriculationOWONA.pdf
# 'Automating Recipes popularity.gslides'
#  CahierDeChargesUEProjet.gdoc
#  Cheat_Sheets
#  cni.pdf
# 'Colab Notebooks'
# 'Copie traduite de CV.gdoc'
#  cv16_04_22.pdf
#  CV.gdoc
#  CV_OWONA_Edouard.gdoc
#  CVOWONAEouard_08_23.docx
#  CVOWONAEouard_08_23.pdf
# 'CVOWONAEouard_10_22 (1).pdf.pdf'
#  CVOWONAEouard_10_22.pdf
#  CVOWONAEouard_10_22.pdf.pdf
#  Dashboard_TpBi.pbix
#  devisLocationChaise.gsheet
#  EN_CV_OWONA_Edouard.gdoc
#  ExposéRMSprop
#  FichiersTP.zip
#  FR_CV_OWONA_Edouard.gdoc
#  Github
#  Groupe10UEProjet.gdoc
# 'https:%2Fdvprogram.state.gov%2Fapplication.aspx 2.pdf'
#  https:%2Fdvprogram.state.gov%2Fapplication.aspx.pdf
# 'input file modified.gsheet'
# 'Mon projet professionnel.docx'
# 'Opportunités '
#  Others
#  owonaEd.jpeg
# 'Please give me an example of survival table with all the associated calculus .gsheet'
#  PO-20221118-000055.pdf
# 'Practical Exam Data Analyst Presentation.gslides'
# ...

# %%
import pandas as pd

# %%
data = pd.read_csv("/gdrive/MyDrive/deep_learning_courses/data/california_housing_train.csv")

# %%
data.head()
# Out:
#    longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0    -114.31     34.19                15.0       5612.0          1283.0
# 1    -114.47     34.40                19.0       7650.0          1901.0
# 2    -114.56     33.69                17.0        720.0           174.0
# 3    -114.57     33.64                14.0       1501.0           337.0
# 4    -114.57     33.57                20.0       1454.0           326.0
#
#    population  households  median_income  median_house_value
# 0      1015.0       472.0         1.4936             66900.0
# 1      1129.0       463.0         1.8200             80100.0
# 2       333.0       117.0         1.6509             85700.0
# 3       515.0       226.0         3.1917             73400.0
# 4       624.0       262.0         1.9250             65500.0
